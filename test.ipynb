# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import torch
torch.cuda.is_available()
# Out:
# True

# %%
torch.device('cuda')
# Out:
# device(type='cuda')

# %%
torch.cuda.device_count()
# Out:
# 3

# %%
print(torch.version.cuda)
# Out:
# 11.0

# %%
plt.imshow(mpimg.imread('saved_model/00019-CelebA-HQ-img-mirror-celeba512-mat-lr0.001-TwoStageLoss-pr0.1-nopl-batch8-tc0.5-sm0.5-ema10-noaug/reals.png'))

# %%
plt.imshow(mpimg.imread('saved_model/00019-CelebA-HQ-img-mirror-celeba512-mat-lr0.001-TwoStageLoss-pr0.1-nopl-batch8-tc0.5-sm0.5-ema10-noaug/masks.png'), cmap='gray')

# %%
plt.imshow(mpimg.imread('saved_model/00019-CelebA-HQ-img-mirror-celeba512-mat-lr0.001-TwoStageLoss-pr0.1-nopl-batch8-tc0.5-sm0.5-ema10-noaug/fakes_init.png'))

# %%
plt.imshow(mpimg.imread('saved_model/00019-CelebA-HQ-img-mirror-celeba512-mat-lr0.001-TwoStageLoss-pr0.1-nopl-batch8-tc0.5-sm0.5-ema10-noaug/fakes000000.png'))

# %%
plt.imshow(mpimg.imread('saved_model/00019-CelebA-HQ-img-mirror-celeba512-mat-lr0.001-TwoStageLoss-pr0.1-nopl-batch8-tc0.5-sm0.5-ema10-noaug/fakes000040.png'))

# %%
plt.imshow(mpimg.imread('saved_model/00019-CelebA-HQ-img-mirror-celeba512-mat-lr0.001-TwoStageLoss-pr0.1-nopl-batch8-tc0.5-sm0.5-ema10-noaug/fakes000080.png'))

# %%
plt.imshow(mpimg.imread('saved_model/00019-CelebA-HQ-img-mirror-celeba512-mat-lr0.001-TwoStageLoss-pr0.1-nopl-batch8-tc0.5-sm0.5-ema10-noaug/fakes000120.png'))

# %%
plt.imshow(mpimg.imread('saved_model/00019-CelebA-HQ-img-mirror-celeba512-mat-lr0.001-TwoStageLoss-pr0.1-nopl-batch8-tc0.5-sm0.5-ema10-noaug/fakes000160.png'))

# %%
plt.imshow(mpimg.imread('saved_model/00019-CelebA-HQ-img-mirror-celeba512-mat-lr0.001-TwoStageLoss-pr0.1-nopl-batch8-tc0.5-sm0.5-ema10-noaug/fakes000200.png'))
